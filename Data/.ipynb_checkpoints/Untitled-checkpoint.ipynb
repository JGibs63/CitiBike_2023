# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import csv
import os
pd.set_option('display.max_rows', None)
import datetime as dt
import glob

# %%
files = glob.glob('/Users/joshuagibson/Desktop/ClassWork/VU-VIRT-DATA-PT-08-2023-U-LOLC/lesson/18-Tableau/Citi Bike Project/Data/*.csv')


# Initialize an empty list to store DataFrames
csv_list = []

# Loop over the files
for file in files:
    df = pd.read_csv(file)
    csv_list.append(df)

# Concatenate DataFrames
combined_df = pd.concat(csv_list, ignore_index=True)

# Display the combined DataFrame
combined_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  ...  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411  ...
# ...

# %%
combined_df.tail()
# Out:
#                   ride_id rideable_type           started_at  \
# 2528774  3F8FD9A051C0E3DA   docked_bike  2021-02-24 18:05:45
# 2528775  B91F3593C0C06D04   docked_bike  2021-02-22 18:22:04
# 2528776  A790954A017D07CB   docked_bike  2021-02-13 12:21:49
# 2528777  42B1932D06CEE034   docked_bike  2021-02-25 11:20:29
# 2528778  F71732ECE7CD02CF   docked_bike  2021-02-19 13:59:22
#
#                     ended_at start_station_name start_station_id  \
# 2528774  2021-02-24 18:12:27     Columbus Drive            JC014
# 2528775  2021-02-22 18:28:45     Columbus Drive            JC014
# 2528776  2021-02-13 12:27:51     Columbus Drive            JC014
# 2528777  2021-02-25 11:25:23     Columbus Drive            JC014
# 2528778  2021-02-19 14:05:47     Columbus Drive            JC014
#
#         end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 2528774     Newport Pkwy          JC008  40.718355 -74.038914  40.728745
# ...

# %%
columns_to_drop = ['tripduration', 'starttime', 'stoptime', 'start station id', 'start station name']

# Drop specified columns
combined_df = combined_df.drop(columns=columns_to_drop)

# Display the modified DataFrame
combined_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# ...

# %%
combined_df.tail(100)
# Out:
#                   ride_id rideable_type           started_at  \
# 2528679  17776AA64ECC2B1F   docked_bike  2021-02-19 12:15:34
# 2528680  49FAC22FCB7D16FD   docked_bike  2021-02-26 15:53:19
# 2528681  5AFF2F1DC05FBA02   docked_bike  2021-02-24 14:40:52
# 2528682  E3E4041500F7BE4D   docked_bike  2021-02-25 18:45:39
# 2528683  540A3C3E70153E3D   docked_bike  2021-02-06 12:14:14
# 2528684  8A3804063EC2BEEF   docked_bike  2021-02-20 17:10:24
# 2528685  50FAB81EF5F34CB8   docked_bike  2021-02-15 15:09:10
# 2528686  EE6AB6FE9FB247BE   docked_bike  2021-02-03 18:53:37
# 2528687  ED69B59DBF051D62   docked_bike  2021-02-28 14:16:33
# 2528688  321981FA94362CB1   docked_bike  2021-02-20 10:09:46
# 2528689  11FEAE6A02F9D0B4   docked_bike  2021-02-26 14:51:34
# 2528690  7C2F683DDD1C0002   docked_bike  2021-02-09 22:01:18
# 2528691  B37267685EF0ADAF   docked_bike  2021-02-23 11:36:24
# 2528692  2FA744F6D6EB24E7   docked_bike  2021-02-14 12:56:17
# ...

# %%
date_column = pd.to_datetime(combined_df['started_at'])

# Find the minimum and maximum dates
min_date = date_column.min()
max_date = date_column.max()

# Display the results
print("Minimum Date:", min_date)
print("Maximum Date:", max_date)
# Out:
# Minimum Date: 2021-02-01 00:42:51
# Maximum Date: 2023-12-31 23:59:57
